# %% [markdown]
# # Hail DB Data Extraction

# %% [markdown]
# # `.env`
#
# - Make sure to create a `.env` file with:
# ```
# AZURE_ENDPOINT=...
# AZURE_API_KEY=...
# AZURE_MODEL=...
# ```

# %% [markdown]
# # Define LLM Inference Code

# %%
# !pip install openai python-dotenv
# Out:
# Collecting openai
#   Downloading openai-1.17.0-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.3/268.3 kB 4.0 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: python-dotenv, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.17.0 python-dotenv-1.0.1

# %%
import os
import re
import json
from openai import AzureOpenAI
from typing import Optional

class GPTModel:
  def __init__(self, api_key: str, endpoint: str, model: str):
    self.client = AzureOpenAI(
      azure_endpoint = endpoint,
      api_key = api_key,
      api_version = "2024-02-01"
    )
    self.model = model

  @staticmethod
  def extract_json_content(s: str) -> str:
    # Define the regex pattern to match `json<content>`
    pattern = r'^```json(.*)```$'

    # Search for the pattern
    match = re.search(pattern, s, re.DOTALL)

    # If a match is found, return the content within the wrapper
    if match:
        return match.group(1).strip()
    else:
        # Return the original string or handle as needed
        return s

  @staticmethod
  def json_to_dict(s: str) -> dict:
    return json.loads(s)

  def call(self, user_msg: str, sys_msg: Optional[str] = None) -> str:
    messages = []

    if sys_msg:
      messages.append({"role": "system", "content": sys_msg})
    messages.append({"role": "user", "content": user_msg})

    response = self.client.chat.completions.create(
        model=self.model,
        messages=messages,
    )

    res = response.choices[0].message.content
    res = GPTModel.extract_json_content(res)
    res = GPTModel.json_to_dict(res)
    return res

# %%
from dotenv import load_dotenv
load_dotenv()

AZURE_ENDPOINT = os.getenv('AZURE_ENDPOINT')
AZURE_API_KEY = os.getenv('AZURE_API_KEY')
AZURE_MODEL = os.getenv('AZURE_MODEL')

gpt_model = GPTModel(
    api_key=AZURE_API_KEY,
    endpoint=AZURE_ENDPOINT,
    model=AZURE_MODEL
)

# %% [markdown]
# # Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df_hail_db = pd.read_csv('/content/drive/My Drive/Hackathon_20231007/Hail_db/hail_db_with_size_v20230204.csv')

# %%
import pandas as pd

df_hail_reference_objects = pd.read_csv('/content/drive/My Drive/Hackathon_20231007/Hail_db/HailReferenceObjects.csv')

# %%
hail_sizes_sorted = [hail_size for hail_size in sorted(df_hail_reference_objects["Reference Object"].tolist()) if hail_size != "unknown"]

# %%
print('\n'.join(hail_sizes_sorted))
# Out:
# 3/4 of golf ball
# M & M
# acorn
# apple
# baseball
# blueberry
# bottle cap
# button
# cherry
# chickpea
# chocolate chip
# cochonnet
# dime
# double pea
# estimated 1 inch
# estimated 1.5 inch
# estimated 100mm
# estimated 10mm
# estimated 11mm
# estimated 12mm
# estimated 14mm
# estimated 15mm
# estimated 18mm
# estimated 19mm
# estimated 2 inches
# estimated 20mm
# estimated 21mm
# estimated 22mm
# estimated 24mm
# estimated 25mm
# estimated 26mm
# estimated 27mm
# estimated 28mm
# estimated 30mm
# estimated 32mm
# estimated 35mm
# estimated 38mm
# estimated 40mm
# estimated 45mm
# estimated 50mm
# estimated 55mm
# estimated 60mm
# estimated 65mm
# estimated 6mm
# estimated 70mm
# estimated 75mm
# estimated 80mm
# estimated 90mm
# estimated 95mm
# estimated half inch
# golf ball
# grape
# grapefruit
# half dime
# half dollar
# half golf ball
# half penny
# hand palm (F)
# hand palm (M)
# hen egg
# ice cube
# large
# large grape
# large marble
# larger than baseball
# larger than dime
# larger than golf ball
# larger than hen egg
# larger than loonie
# larger than marble
# larger than nickel
# larger than pea
# larger than plum
# larger than quarter
# larger than tennis ball
# larger than toonie
# lemon
# loonie
# marble
# measured 123mm
# measured 12mm
# measured 20mm
# measured 21mm
# measured 22mm
# measured 23mm
# measured 25mm
# measured 28mm
# measured 29mm
# measured 30mm
# measured 31mm
# measured 32mm
# measured 35mm
# measured 37mm
# measured 40mm
# measured 42mm
# measured 43mm
# measured 45mm
# measured 48mm
# measured 49mm
# measured 50mm
# measured 52mm
# measured 54mm
# measured 55mm
# measured 57mm
# measured 60mm
# measured 61mm
# measured 75mm
# measured 83mm
# mothball
# nickel
# no hail
# non-severe
# paintball
# pea
# peach pit
# pencil-top eraser
# penny
# pigeon egg
# ping pong
# pinky nail
# plum
# pool table ball
# pop corn
# quail egg
# quarter
# rice
# severe
# shot
# shuffle board rock
# small
# small berry
# small grape
# small gumball
# small walnut
# smaller than baseball
# smaller than dime
# smaller than golf ball
# smaller than loonie
# smaller than loonie
# smaller than nickel
# smaller than ping pong
# smaller than quarter
# smaller than tennis ball
# smartie
# softball
# strawberry
# tea cup
# tennis
# toonie
# twice golf ball
# two toonies
# walnut

# %% [markdown]
# # Extraction Information

# %%
# !pip install fuzzywuzzy python-Levenshtein
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.25.1-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.25.1 (from python-Levenshtein)
#   Downloading Levenshtein-0.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 6.7 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.8.0 (from Levenshtein==0.25.1->python-Levenshtein)
#   Downloading rapidfuzz-3.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 49.5 MB/s eta 0:00:00
# Installing collected packages: fuzzywuzzy, rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.25.1 fuzzywuzzy-0.18.0 python-Levenshtein-0.25.1 rapidfuzz-3.8.1

# %%
from pydantic import BaseModel

class Response(BaseModel):
  reference_object: str
  reference_location: str
  reference_object_flag: str
  picture_flag: str
  source: str
  social_media_link: str
  hail_start_time: str
  time_flag: str
  hail_damage: str
  hail_accumulation: str
  associated_rain_amount: str
  associated_severe_weather: str

response_example = Response(
    reference_object="marble",
    reference_location="Toronto, ON",
    reference_object_flag="visual estimate from up-close",
    picture_flag="picture",
    source="social media",
    social_media_link="https://www.twitter.com",
    hail_start_time="2023-01-01 00:00:00",
    time_flag="watch",
    hail_damage="unknown",
    hail_accumulation="unknown",
    associated_rain_amount="unknown",
    associated_severe_weather="unknown"
)

def extract_info_from_note(gpt_model, df_hail_db, hail_sizes, row_index):
  note = df_hail_db.loc[row_index, 'Notes']

  newline = "\n"

  sys_msg = f"Your response to the user's instruction should follow the following JSON format: {response_example.json()}"

  user_msg = f"""
Instruction:
Given the following note about hail observation below, extract the following information:
- reference_object: size of the observed hail, choose one of the hail size options from below
- reference_location: location of the observed hail, such as neighborhood/intersection, town, and/or province code in capital letter
- reference_object_flag: how the hail size was measured (ex: caliper, ruler, measuring tape, side by side with <reference object>, visual estimate from up-close, visual estimate from far-off, etc...)
- picture_flag: was a picture or video taken (e.g.: picture, video)
- source: where did the note come from (ex: social media, phone-in, phone-out, email, storm spotter, Nav Canada stations at airports, CoCoRaSH, etc...)
- social_media_link: social media link if it exists
- hail_start_time: esimated start time of hail in the format of YYYY-MM-DD HH:MM:SS
- time_flag: how was the time estimated (ex: radar, watch, GPS, approximate, timing of social media post)
- hail_damage: damage/injury associated with hail
- hail_accumulation: how much hail has accumulated (ex: sparse, fully covered, Xmm of accumulation)
- associated_rain_amount: how much rain was associated with the hail
- associated_severe_weather: any other severe weather associated with the hail (ex: tornado, high wind, heavy wind)
For any of the fields above, if the information cannot be found or is false, output: unknown

Hail Size Options:
{newline.join(hail_sizes)}

Note:
{note}
"""

  res = gpt_model.call(user_msg, sys_msg)

  return res

# %%
from fuzzywuzzy import process

def find_closest_match(items, target):
    if target in set(items):
      return target

    closest_match, score = process.extractOne(target, items)

    return closest_match

# %%
# Adjust as needed
start_index = 5000
end_index = 7000
thread_max_workers = 5

# %%
# %%time
import pandas as pd
from google.colab import files
from tqdm import tqdm

# Extracting Information

from concurrent.futures import ThreadPoolExecutor, as_completed

def process_row(i, gpt_model, df_hail_db, hail_sizes_sorted):
    try:
        res = extract_info_from_note(
            gpt_model=gpt_model,
            df_hail_db=df_hail_db,
            hail_sizes=hail_sizes_sorted,
            row_index=i,
        )
        return {
            "row_index": i,
            "success": True,
            "data": {
                "row_index": i,
                "reference_object": res.get('reference_object', 'unknown'),
                "reference_location": res.get('reference_location', 'unknown'),
                "reference_object_flag": res.get('reference_object_flag', 'unknown'),
                "picture_flag": res.get('picture_flag', 'unknown'),
                "source": res.get('source', 'unknown'),
                "social_media_link": res.get('social_media_link', 'unknown'),
                "hail_start_time": res.get('hail_start_time', 'unknown'),
                "time_flag": res.get('time_flag', 'unknown'),
                "hail_damage": res.get('hail_damage', 'unknown'),
                "hail_accumulation": res.get('hail_accumulation', 'unknown'),
                "associated_rain_amount": res.get('associated_rain_amount', 'unknown'),
                "associated_severe_weather": res.get('associated_severe_weather', 'unknown'),
            }
        }
    except Exception as e:
        print(f"An error occurred processing row {i}: {e}")
        return {"row_index": i, "success": False}

# Example of how you'd call this in your main code
df_extracted_info = []
missed_index_list = []

with ThreadPoolExecutor(max_workers=thread_max_workers) as executor:
    # Prepare futures
    futures = [executor.submit(process_row, i, gpt_model, df_hail_db, hail_sizes_sorted)
               for i in range(start_index, end_index)]

    # Process results as they become available, with tqdm for progress tracking
    for future in tqdm(as_completed(futures), total=len(futures), desc="Processing rows"):
        result = future.result()
        if result["success"]:
            df_extracted_info.append(result["data"])
        else:
            missed_index_list.append(result["row_index"])

print(f"Missed indices: {missed_index_list}")

# Matching Reference Objects

hail_sizes_sorted_with_unknown = hail_sizes_sorted + ['unknown']

for row in df_extracted_info:
  matched_reference_object = find_closest_match(hail_sizes_sorted_with_unknown, row['reference_object'])
  if matched_reference_object != row['reference_object']:
    print(f"Reference object mismatch for row {row['row_index']}: {matched_reference_object} replacing {row['reference_object']}")
  row['reference_object'] = matched_reference_object

# Saving File

df_extracted_info_pd = pd.DataFrame(df_extracted_info)
df_extracted_info_pd = df_extracted_info_pd.sort_values(by='row_index', ascending=True)
print(df_extracted_info_pd)
filename = f'extracted_info_{start_index}_to_{end_index}.csv'
df_extracted_info_pd.to_csv(filename, index=False)
files.download(filename)
# Out:
# Processing rows:  29%|██▊       | 574/2000 [28:48<1:03:40,  2.68s/it]
# An error occurred processing row 5564: Extra data: line 2 column 1 (char 401)
# Processing rows: 100%|██████████| 2000/2000 [1:29:43<00:00,  2.69s/it]
# Missed indices: [5564]
# Reference object mismatch for row 5002: nickel replacing nickel to quarter
# Reference object mismatch for row 5003: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 5006: golf ball replacing quarter to golf ball
# Reference object mismatch for row 5012: loonie replacing quarter to loonie
# Reference object mismatch for row 5021: nickel replacing pea to nickel
# Reference object mismatch for row 5067: nickel replacing nickel to quarter
# Reference object mismatch for row 5109: marble replacing marble to quarter
# Reference object mismatch for row 5111: nickel replacing pea to nickel
# Reference object mismatch for row 5114: penny replacing smaller than penny
# Reference object mismatch for row 5154: nickel replacing nickel to quarter
# Reference object mismatch for row 5166: dime replacing dime to nickel
# Reference object mismatch for row 5184: marble replacing pea to marble
# Reference object mismatch for row 5198: nickel replacing pea to nickel sized hail
# Reference object mismatch for row 5202: quarter replacing quarter to toonie
# Reference object mismatch for row 5208: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 5219: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 5238: nickel replacing nickel to quarter
# Reference object mismatch for row 5244: toonie replacing toonies
# Reference object mismatch for row 5243: nickel replacing nickel to quarter
# Reference object mismatch for row 5258: dime replacing dime to nickel
# Reference object mismatch for row 5264: dime replacing dime to nickel
# Reference object mismatch for row 5262: nickel replacing pea to nickel sized hail
# Reference object mismatch for row 5268: dime replacing dime - quarter
# Reference object mismatch for row 5267: dime replacing dime to nickel
# Reference object mismatch for row 5269: dime replacing Dime-Quarter
# Reference object mismatch for row 5287: loonie replacing loonie to toonie sized
# Reference object mismatch for row 5289: dime replacing pea-dime
# Reference object mismatch for row 5314: dime replacing pea to dime-sized hail
# Reference object mismatch for row 5315: dime replacing pea to dime size hail
# Reference object mismatch for row 5319: dime replacing dime -Golf ball
# Reference object mismatch for row 5326: mothball replacing pea to mothball
# Reference object mismatch for row 5328: loonie replacing loonie/toonie
# Reference object mismatch for row 5330: mothball replacing pea to mothball
# Reference object mismatch for row 5336: estimated 10mm replacing estimated 13mm
# Reference object mismatch for row 5366: pea replacing sub-pea
# Reference object mismatch for row 5365: pea replacing smaller than pea
# Reference object mismatch for row 5371: pea replacing smaller than pea
# Reference object mismatch for row 5376: golf ball replacing loonie to golf ball
# Reference object mismatch for row 5386: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 5391: loonie replacing loonie to toonie
# Reference object mismatch for row 5387: loonie replacing quarter to loonie
# Reference object mismatch for row 5402: estimated 30mm replacing estimated 3mm
# Reference object mismatch for row 5412: nickel replacing nickel to quarter
# Reference object mismatch for row 5416: estimated half inch replacing half inch
# Reference object mismatch for row 5414: nickel replacing nickel to quarter
# Reference object mismatch for row 5426: dime replacing dime to nickel
# Reference object mismatch for row 5430: pea replacing sub-pea sized
# Reference object mismatch for row 5432: dime replacing dime to nickel
# Reference object mismatch for row 5428: nickel replacing nickel to quarter
# Reference object mismatch for row 5472: nickel replacing pea to nickel
# Reference object mismatch for row 5481: pea replacing sub-pea
# Reference object mismatch for row 5492: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 5500: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 5512: estimated 15mm replacing estimated 5mm
# Reference object mismatch for row 5541: grape replacing quarter, large grape, small golfball
# Reference object mismatch for row 5549: quarter replacing quarter and golfball
# Reference object mismatch for row 5554: baseball replacing golf ball - baseball
# Reference object mismatch for row 5576: pea replacing quarter, pea
# Reference object mismatch for row 5588: loonie replacing loonie, pea
# Reference object mismatch for row 5591: estimated 1.5 inch replacing estimated 3.5 inches
# Reference object mismatch for row 5597: nickel replacing nickel to quarter
# Reference object mismatch for row 5595: golf ball replacing quarters to golf balls
# Reference object mismatch for row 5599: dime replacing dime to nickel
# Reference object mismatch for row 5605: pea replacing quarter, pea
# Reference object mismatch for row 5610: dime replacing dime to nickel size hail
# Reference object mismatch for row 5624: dime replacing dime to nickel
# Reference object mismatch for row 5642: dime replacing pea to dime
# Reference object mismatch for row 5675: golf ball replacing toonie to golf ball
# Reference object mismatch for row 5702: estimated 15mm replacing estimated 5mm
# Reference object mismatch for row 5711: cherry replacing large cherry, marble
# Reference object mismatch for row 5715: golf ball replacing toonie to golf ball
# Reference object mismatch for row 5722: golf ball replacing ping pong,golf ball
# Reference object mismatch for row 5740: dime replacing pea to dime
# Reference object mismatch for row 5745: loonie replacing nickel to loonie
# Reference object mismatch for row 5790: pea replacing smaller than pea
# Reference object mismatch for row 5815: dime replacing pea to dime sized hail
# Reference object mismatch for row 5846: loonie replacing loonie to toonie
# Reference object mismatch for row 5859: measured 23mm replacing measured 38mm
# Reference object mismatch for row 5869: loonie replacing quarter to loonie
# Reference object mismatch for row 5870: nickel replacing Nickel to Quarter
# Reference object mismatch for row 5877: nickel replacing nickel to toonie
# Reference object mismatch for row 5887: M & M replacing centimetre
# Reference object mismatch for row 5890: golf ball replacing near golf ball
# Reference object mismatch for row 5893: nickel replacing nickel to quarter-sized
# Reference object mismatch for row 5922: nickel replacing nickel to quarter
# Reference object mismatch for row 5952: pea replacing pea to quarter
# Reference object mismatch for row 5954: pea replacing smaller than pea
# Reference object mismatch for row 5955: quarter replacing quarters
# Reference object mismatch for row 5964: loonie replacing quarter to loonie
# Reference object mismatch for row 5979: loonie replacing quarter to loonie
# Reference object mismatch for row 5986: quarter replacing estimated quarter size
# Reference object mismatch for row 5993: golf ball replacing ping pong ball to golf ball
# Reference object mismatch for row 6007: ping pong replacing ping pong ball to golfball
# Reference object mismatch for row 6015: dime replacing dime to nickel
# Reference object mismatch for row 6016: quarter replacing estimated quarter size
# Reference object mismatch for row 6048: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 6054: half dollar replacing toonies and half dollars
# Reference object mismatch for row 6065: ping pong replacing ping pong balls
# Reference object mismatch for row 6090: grape replacing grape to quarter
# Reference object mismatch for row 6097: nickel replacing pea to Nickel
# Reference object mismatch for row 6104: dime replacing pea to dime-sized hail
# Reference object mismatch for row 6117: estimated 12mm replacing estimated 2mm
# Reference object mismatch for row 6130: pea replacing sub-pea
# Reference object mismatch for row 6137: loonie replacing loonie to quarter
# Reference object mismatch for row 6141: pea replacing sub-pea
# Reference object mismatch for row 6146: estimated 14mm replacing estimated 47mm
# Reference object mismatch for row 6148: loonie replacing loonie to toonie
# Reference object mismatch for row 6149: estimated 10mm replacing estimated 13mm
# Reference object mismatch for row 6143: golf ball replacing golf ball to base ball
# Reference object mismatch for row 6144: loonie replacing quarter to loonie
# Reference object mismatch for row 6154: nickel replacing nickel to quarter
# Reference object mismatch for row 6198: estimated 1 inch replacing inch
# Reference object mismatch for row 6203: dime replacing dime, toonie
# Reference object mismatch for row 6216: dime replacing dime to nickel size
# Reference object mismatch for row 6230: larger than tennis ball replacing tennis ball
# Reference object mismatch for row 6246: dime replacing dime, nickel
# Reference object mismatch for row 6269: dime replacing pea to dime-sized
# Reference object mismatch for row 6273: pea replacing pea-quarter-sized hail
# Reference object mismatch for row 6280: loonie replacing loonie to toonie
# Reference object mismatch for row 6328: loonie replacing loonie-toonie
# Reference object mismatch for row 6340: dime replacing dime, pea, quarter
# Reference object mismatch for row 6346: dime replacing nickel, dime
# Reference object mismatch for row 6355: half dollar replacing half-dollar
# Reference object mismatch for row 6356: golf ball replacing quarter to golf ball
# Reference object mismatch for row 6364: dime replacing pea, dime
# Reference object mismatch for row 6370: quarter replacing quarter, walnut
# Reference object mismatch for row 6393: nickel replacing nickel/quarter
# Reference object mismatch for row 6394: toonie replacing Toonie
# Reference object mismatch for row 6397: dime replacing pea to dime
# Reference object mismatch for row 6399: nickel replacing nickel to quarter
# Reference object mismatch for row 6408: estimated 10mm replacing estimated 31mm
# Reference object mismatch for row 6416: dime replacing dime to nickel
# Reference object mismatch for row 6427: golf ball replacing pea to golf ball
# Reference object mismatch for row 6423: golf ball replacing marble to golf ball
# Reference object mismatch for row 6429: marble replacing quarter/marble
# Reference object mismatch for row 6431: nickel replacing pea to nickel
# Reference object mismatch for row 6444: quarter replacing pea to quarter-sized hail
# Reference object mismatch for row 6445: dime replacing pea to dime
# Reference object mismatch for row 6447: toonie replacing between toonie and walnut sized
# Reference object mismatch for row 6455: loonie replacing quarter to loonie
# Reference object mismatch for row 6456: nickel replacing pea to nickel
# Reference object mismatch for row 6464: loonie replacing quarter to loonie size
# Reference object mismatch for row 6472: dime replacing pea-dime
# Reference object mismatch for row 6467: tennis replacing tennis balls
# Reference object mismatch for row 6474: loonie replacing Loonie-Toonie
# Reference object mismatch for row 6471: dime replacing pea, dime
# Reference object mismatch for row 6475: golf ball replacing quarter loonie, golf ball
# Reference object mismatch for row 6488: golf ball replacing quarter, loonie, golf ball
# Reference object mismatch for row 6493: nickel replacing nickel-quarter
# Reference object mismatch for row 6506: loonie replacing nickel to loonie
# Reference object mismatch for row 6508: nickel replacing dime, quarter, pea, almost nickel-sized
# Reference object mismatch for row 6516: small replacing very small
# Reference object mismatch for row 6518: pea replacing pea to walnut-sized hail
# Reference object mismatch for row 6520: dime replacing dime, golf ball
# Reference object mismatch for row 6534: marble replacing pea - marble
# Reference object mismatch for row 6539: dime replacing pea to dime
# Reference object mismatch for row 6532: pea replacing smaller than pea
# Reference object mismatch for row 6542: nickel replacing nickel to walnut
# Reference object mismatch for row 6570: nickel replacing pea to nickel size hail
# Reference object mismatch for row 6575: pea replacing sub-pea
# Reference object mismatch for row 6576: pea replacing sub-pea
# Reference object mismatch for row 6574: pea replacing smaller than pea
# Reference object mismatch for row 6577: pea replacing smaller than pea
# Reference object mismatch for row 6581: dime replacing pea to dime
# Reference object mismatch for row 6597: measured 123mm replacing measured 13mm
# Reference object mismatch for row 6602: dime replacing dime to nickel
# Reference object mismatch for row 6605: nickel replacing pea to nickel
# Reference object mismatch for row 6642: pea replacing smaller than pea
# Reference object mismatch for row 6643: small replacing very small
# Reference object mismatch for row 6650: pea replacing smaller than pea
# Reference object mismatch for row 6658: dime replacing pea, dime
# Reference object mismatch for row 6676: golf ball replacing toonie to golf ball
# Reference object mismatch for row 6684: dime replacing dime to nickel size hail
# Reference object mismatch for row 6685: pea replacing sub-pea
# Reference object mismatch for row 6689: mothball replacing mothball, pea
# Reference object mismatch for row 6702: pea replacing sub-pea
# Reference object mismatch for row 6711: loonie replacing loonie, nickel
# Reference object mismatch for row 6728: ping pong replacing quarter, ping pong
# Reference object mismatch for row 6760: loonie replacing nickel to loonie size hail
# Reference object mismatch for row 6774: estimated 14mm replacing ping pong, loonie, estimated 14mm
# Reference object mismatch for row 6781: baseball replacing baseball, tennis
# Reference object mismatch for row 6821: dime replacing dime to nickel
# Reference object mismatch for row 6831: nickel replacing nickel to quarter
# Reference object mismatch for row 6839: golf ball replacing golf ball to tennis ball
# Reference object mismatch for row 6842: golf ball replacing golf ball, loonie
# Reference object mismatch for row 6861: estimated half inch replacing half inch
# Reference object mismatch for row 6900: dime replacing pea to dime size
# Reference object mismatch for row 6903: dime replacing pea to dime size
# Reference object mismatch for row 6906: quarter replacing quarter, toonie
# Reference object mismatch for row 6927: nickel replacing nickel to quarter
# Reference object mismatch for row 6928: loonie replacing loonie, twoonie
# Reference object mismatch for row 6943: larger than tennis ball replacing Tennis Ball
# Reference object mismatch for row 6961: golf ball replacing tennis ball, golf ball, pea, quarter
# Reference object mismatch for row 6965: golf ball replacing quarter, golf ball
# Reference object mismatch for row 6968: golf ball replacing quarter to golf ball size
# Reference object mismatch for row 6973: estimated 6mm replacing estimated 76mm
# Reference object mismatch for row 6974: dime replacing dime, ping pong
# Reference object mismatch for row 6978: pea replacing pea to quarter
# Reference object mismatch for row 6982: dime replacing pea to dime
# Reference object mismatch for row 6988: quarter replacing Quarter
#       row_index         reference_object                reference_location  \
# 1          5000                ping pong                       Bassano, AB
# 2          5001                   nickel                           Calgary
# 3          5002                   nickel                          Cochrane
# 4          5003  larger than tennis ball                           Calgary
# 0          5004                ping pong                            Balzac
# ...         ...                      ...                               ...
# 1991       6995                      pea                      Mantario, SK
# 1994       6996                      pea  Dalmeny, SK and Martensville, SK
# 1998       6997           measured 123mm                   Markerville, AB
# 1996       6998           estimated 30mm                           unknown
# 1995       6999                  unknown                           unknown
#
#               reference_object_flag picture_flag        source  \
# 1     visual estimate from up-close      unknown  storm chaser
# 2     visual estimate from up-close      picture  social media
# 3     visual estimate from up-close      unknown      phone-in
# 4     visual estimate from up-close      picture       unknown
# 0                           unknown      unknown       unknown
# ...                             ...          ...           ...
# 1991                        unknown      unknown     phone-out
# 1994  visual estimate from up-close      unknown  social media
# 1998                      measuring      picture  social media
# 1996                        unknown      picture  social media
# 1995                        unknown      unknown  social media
#
#                                       social_media_link hail_start_time  \
# 1                                               unknown         unknown
# 2                               https://www.twitter.com         unknown
# 3                                               unknown         unknown
# 4                                               unknown         unknown
# 0                                               unknown         unknown
# ...                                                 ...             ...
# 1991                                            unknown         unknown
# 1994  https://www.facebook.com/groups/SaskWT/permali...         unknown
# 1998  https://www.twitter.com/BraydonMoreSo/status/1...         unknown
# 1996  https://twitter.com/lightningmanAB/status/1548...         unknown
# 1995                            https://www.twitter.com         unknown
#
#      time_flag          hail_damage hail_accumulation associated_rain_amount  \
# 1      unknown              unknown           unknown                unknown
# 2      unknown              unknown           unknown                unknown
# 3        radar              unknown           unknown                unknown
# 4      unknown  ruined house siding      Large amount     48.7mm in one hour
# 0      unknown              unknown           unknown                unknown
# ...        ...                  ...               ...                    ...
# 1991   unknown              unknown           unknown                unknown
# 1994   unknown              unknown           unknown                unknown
# 1998   unknown              unknown           unknown                unknown
# 1996   unknown              unknown           unknown                unknown
# 1995   unknown              unknown           unknown                unknown
#
#      associated_severe_weather
# 1                      unknown
# 2                      unknown
# 3                      unknown
# 4               Flash flooding
# 0                      unknown
# ...                        ...
# 1991                   unknown
# 1994                   unknown
# 1998                   unknown
# 1996                   unknown
# 1995                   unknown
#
# [1999 rows x 13 columns]
# CPU times: user 45.7 s, sys: 3.3 s, total: 49 s
# Wall time: 1h 29min 45s

# %% [markdown]
# > Note
#
# - It takes around 40min to process 1k rows.

# %% [markdown]
# # Combine Dataset

# %%
import pandas as pd

df_extracted_info_0_to_1000 = pd.read_csv('extracted_info_0_to_1000.csv')
df_extracted_info_1000_to_3000 = pd.read_csv('extracted_info_1000_to_3000.csv')
df_extracted_info_3000_to_5000 = pd.read_csv('extracted_info_3000_to_5000.csv')
df_extracted_info_5000_to_7000 = pd.read_csv('extracted_info_5000_to_7000.csv')

# %%
from google.colab import files

# 1. Combine Multiple DataFrames
df_extracted_info_combined = pd.concat([df_extracted_info_0_to_1000, df_extracted_info_1000_to_3000, df_extracted_info_3000_to_5000, df_extracted_info_5000_to_7000])

# 2. Check for Missing Rows and Insert New Rows
full_range = pd.DataFrame({'row_index': range(7000)})  # Assuming row_index goes from 0 to 6999
df_extracted_info_combined = df_extracted_info_combined.merge(full_range, on='row_index', how='right')

df_extracted_info_combined.fillna('unknown', inplace=True)  # Replace NaN with 'unknown'

# 3. Sort the DataFrame by 'row_index'
df_extracted_info_combined = df_extracted_info_combined.sort_values(by='row_index')

# 4. Save the DataFrame as a CSV file
df_extracted_info_combined.to_csv('extracted_info_combined.csv', index=False)
files.download('extracted_info_combined.csv')
